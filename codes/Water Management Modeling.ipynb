# %%
import pandas as pd
import numpy as np
import random

# %%
# exponential decay
x = 10
y = 5000*np.exp(-0.1*x)
y.round(2)
# Out:
# 1839.4

# %%
class WaterEnv:
  """When there is a rainfall, 40% of water from rain gets added into the lake,
  50% goes to river and 10% goes into ground water.
  Everyday 10% of lake water and 10% of river water goes into the groundwater
  due to seepage.

  Average daily consumption of water is 1500 lakh liters. Depending on
  increasing or decreasing price per liter, the consumption varies. As the price
  increases, consumption decreases.
  The relationship between consumption and price per liter is given by:

      `current_consumption = 5000 * np.exp(-0.1*current_price)`

  NOTE : Consumption and price follows an exponential decay relationship.
  As the price increases, the consumption decays exponentially.

  From the equation, current_price = 10 (rupees per liter)
  => current_consumption = 1839 (lakh liters per day).

  Amount of rainfall on each day can be set to either "low", "medium" or "high".
  This is assumed to be selected randomly or to be choosen dynamically based
  on the season or the area in which the simulation is being performed.

  The goal of the problem is to maximise the profits of the water supply board.
  Water consumption needs to be lesser when there is less rainfall and high when
  there is higher rainfall, so that the source does not get depleated and water
  continously gets consumed.
  --------------------------------------------------------------------------
  NOTE: Time iterval of the transitions are 1 day. T = 1, 2... n implies,
  1st day, 2nd day... nth day.

  Actions
  -------
  Every day, by looking at the water reserves in lake, river and groundwater,
  It is required to take a decision whether to: "increase price",
  "decrease price" or leave the price constant on that particular day.

  States
  ------
  {'ground_reserve': float,
  'lake_reserve': float,
  'river_reserve': float,
  'current_price': float}

  Rewards
  -------
  The income earned by selling water on that particular day OR number of
  liters consumed on a particular day.
  (When water gets over, the episode ends. Hence the agents would learn to
  maximise the consumption but not let the water reserve go empty)
  """
  def __init__(self):
    """
    Parameters
    ----------
    rainfall_level : str
      Can be "low", "medium" or "high"
    """
    self.avg_rainfall_levels = {
        "low": 10,
        "medium": 70,
        "high": 150
        }
    self.rainfall_level = "medium"
    self.avg_price = 10
    self.action_space = ["increase_price", "decrease_price", "constant_price"]

    self.reset()

  def reset(self):
    self.terminated = False
    # water reserve in each source measured in "lakh liters".
    self.state = {"ground_reserve":1500*20,
                  "lake_reserve":1500*20,
                  "river_reserve":1500*40,
                  "current_price":self.avg_price}

    self.total_reward = 0

  def set_rainfall_level(self, rainfall_level):
    self.rainfall_level = rainfall_level

  def rainfall_simulator(self, level):
    avg = self.avg_rainfall_levels[level]
    std = 5
    rainfall = np.random.normal(avg, 5)
    if rainfall<0:
      ranfall = 0
    return rainfall

  def get_consumption(self):
    # Consumption and price follows an exponential decay relationship.
    # As the price increases, the consumption decays exponentially.
    current_consumption = 5000 * np.exp(-0.1*self.state["current_price"])
    current_consumption = current_consumption.round()
    return current_consumption

  def update_states(self, rainfall):
    """Rainfall : 50% to river, 40% lake and 10% ground water
    10% from river and lake gets added to ground water.
    """
    terminated = False

    lake_reserve = self.state["lake_reserve"]
    ground_reserve = self.state["ground_reserve"]
    river_reserve = self.state["river_reserve"]

    current_consumption = self.current_consumption

    # Rainfall : 50% to river, 40% lake and 10% ground water
    lake_reserve += 0.4*rainfall
    ground_reserve += 0.1*rainfall
    river_reserve += 0.5*rainfall

    # 10% of lake reserve goes into ground water
    ground_reserve += 0.1*lake_reserve
    lake_reserve -= 0.1*lake_reserve

    # 10% of river reserve goes into ground water
    ground_reserve += 0.1*river_reserve
    river_reserve -= 0.1*river_reserve

    # account for current consumption.
    # half of daily consumption is met by river water and the other half by
    # ground water.
    # water for consumption is supplied from river and ground reserves.
    if ground_reserve + river_reserve < current_consumption:
      terminated = True
      return terminated
    if 0.5*current_consumption > ground_reserve:
      # Ground reserve is unable to meet half of the current day's consumption.
      # So, the rest in compensated by the river reserve.
      river_reserve = river_reserve - current_consumption + ground_reserve
      ground_reserve = 0
    elif 0.5*current_consumption > river_reserve:
      # River reserve is unable to meet half of the current day's consumption.
      # So, the rest in compensated by the ground reserve.
      ground_reserve = ground_reserve - current_consumption + river_reserve
      river_reserve = 0
    else:
      ground_reserve -= 0.5*current_consumption
      river_reserve -= 0.5*current_consumption

    # update the states
    self.state["lake_reserve"] = lake_reserve
    self.state["ground_reserve"] = ground_reserve
    self.state["river_reserve"] = river_reserve

    return terminated

  def get_reward(self):
    reward = self.state["current_price"] * self.current_consumption
    return reward

  def step(self, action):
    # Adjust the price according to the action taken
    if action == "increase_price":
      self.state["current_price"]+=1
    elif action == "decrease_price" and self.state["current_price"]>1:
      self.state["current_price"]-=1

    self.current_consumption = self.get_consumption()
    if self.current_consumption < 1:
      self.terminated = True
      reward = 0
      return self.state, reward, self.terminated

    rainfall = self.rainfall_simulator(self.rainfall_level)

    self.terminated = self.update_states(rainfall)

    reward = self.get_reward()

    self.total_reward+=reward

    return self.state, reward, self.terminated

# %% [markdown]
# ### Random actions (random selection of pricing)

# %%
# random actions

# rainfall level can be set to low, medium or high.
rainfall_level = "low"

env = WaterEnv()
env.reset()
env.set_rainfall_level(rainfall_level)

print(env.state)

for i in range(100000):
  action = random.choices(env.action_space)[0]
  state, reward, terminated = env.step(action)
  # print(state, reward, terminated)
  if terminated:
    print("Water reserves depleated")
    break

print(env.state)
print("Days sustained: ", i)
print("Total_reward: ", env.total_reward)
# Out:
# {'ground_reserve': 30000, 'lake_reserve': 30000, 'river_reserve': 60000, 'current_price': 10}
# Water reserves depleated
# {'ground_reserve': 1046.9141310685804, 'lake_reserve': 66.95355915609512, 'river_reserve': 0, 'current_price': 13}
# Days sustained:  65
# Total_reward:  1200893.0

# %% [markdown]
# ### Always increase the price

# %%
# Always increase price

# rainfall level can be set to low, medium or high.
rainfall_level = "low"

env = WaterEnv()

env.reset()
env.set_rainfall_level(rainfall_level)

for i in range(100000):
  action = "increase_price"
  state, reward, terminated = env.step(action)
  print(state, reward, terminated)
  if terminated:
    break

print("Days sustained: ", i)
print("Total_reward: ", env.total_reward)
# Out:
# {'ground_reserve': 38169.17488922471, 'lake_reserve': 27002.22610589945, 'river_reserve': 53170.78263237431, 'current_price': 11} 18304.0 False
# {'ground_reserve': 45434.1270080966, 'lake_reserve': 24303.237433288577, 'river_reserve': 47102.24679161071, 'current_price': 12} 18072.0 False
# {'ground_reserve': 51892.951771379856, 'lake_reserve': 21872.489914620768, 'river_reserve': 41709.99239327595, 'current_price': 13} 17719.0 False
# {'ground_reserve': 57635.60561111071, 'lake_reserve': 19686.95681378408, 'river_reserve': 36924.638017230085, 'current_price': 14} 17262.0 False
# {'ground_reserve': 62740.25076597082, 'lake_reserve': 17721.076089422142, 'river_reserve': 32677.692911777667, 'current_price': 15} 16740.0 False
# {'ground_reserve': 67276.47862919501, 'lake_reserve': 15950.580831624751, 'river_reserve': 28907.439059530927, 'current_price': 16} 16144.0 False
# {'ground_reserve': 71307.8231066641, 'lake_reserve': 14359.392726395283, 'river_reserve': 25565.032625994092, 'current_price': 17} 15521.0 False
# {'ground_reserve': 74890.2560239065, 'lake_reserve': 12929.119440709703, 'river_reserve': 22602.611847087115, 'current_price': 18} 14868.0 False
# {'ground_reserve': 78070.50915639068, 'lake_reserve': 11638.253819447229, 'river_reserve': 19970.908565889025, 'current_price': 19} 14212.0 False
# {'ground_reserve': 80895.39929670948, 'lake_reserve': 10479.115830358649, 'river_reserve': 17641.1769503703, 'current_price': 20} 13540.0 False
# {'ground_reserve': 83403.49927635478, 'lake_reserve': 9435.12768188099, 'river_reserve': 15575.963548531028, 'current_price': 21} 12852.0 False
# {'ground_reserve': 85630.18289301087, 'lake_reserve': 8496.4929015948, 'river_reserve': 13747.464678555312, 'current_price': 22} 12188.0 False
# {'ground_reserve': 87606.4597652747, 'lake_reserve': 7651.355196327817, 'river_reserve': 12127.857691815401, 'current_price': 23} 11523.0 False
# {'ground_reserve': 89358.36047866548, 'lake_reserve': 6888.0754285241355, 'river_reserve': 10690.391612420237, 'current_price': 24} 10896.0 False
# {'ground_reserve': 90913.06171165634, 'lake_reserve': 6202.781729896535, 'river_reserve': 9420.74475645923, 'current_price': 25} 10250.0 False
# {'ground_reserve': 92291.57778378266, 'lake_reserve': 5585.655306678819, 'river_reserve': 8297.10996802823, 'current_price': 26} 9646.0 False
# {'ground_reserve': 93513.63369403669, 'lake_reserve': 5030.461238126699, 'river_reserve': 7303.613298870108, 'current_price': 27} 9072.0 False
# {'ground_reserve': 94596.88980523119, 'lake_reserve': 4530.917833777878, 'river_reserve': 6425.630368312908, 'current_price': 28} 8512.0 False
# {'ground_reserve': 95557.07844898487, 'lake_reserve': 4081.6796108003828, 'river_reserve': 5650.384281981983, 'current_price': 29} 7975.0 False
# {'ground_reserve': 96406.485427346, 'lake_reserve': 3674.8390816668543, 'river_reserve': 4962.505143716921, 'current_price': 30} 7470.0 False
# {'ground_reserve': 97159.28123438584, 'lake_reserve': 3310.3135862398103, 'river_reserve': 4357.452645269781, 'current_price': 31} 6975.0 False
# {'ground_reserve': 97825.87992479667, 'lake_reserve': 2982.7345655819136, 'river_reserve': 3824.022803200408, 'current_price': 32} 6528.0 False
# {'ground_reserve': 98417.59664502656, 'lake_reserve': 2690.222972216333, 'river_reserve': 3356.8228518711303, 'current_price': 33} 6072.0 False
# {'ground_reserve': 98940.36869635875, 'lake_reserve': 2424.1706161128254, 'river_reserve': 2941.352993081675, 'current_price': 34} 5678.0 False
# {'ground_reserve': 99404.02764181602, 'lake_reserve': 2186.692346257388, 'river_reserve': 2577.891183468314, 'current_price': 35} 5285.0 False
# {'ground_reserve': 99814.69672643316, 'lake_reserve': 1973.1592347476799, 'river_reserve': 2258.0222190165205, 'current_price': 36} 4932.0 False
# {'ground_reserve': 100177.51462752512, 'lake_reserve': 1779.0639010497061, 'river_reserve': 1974.2457343358615, 'current_price': 37} 4588.0 False
# {'ground_reserve': 100499.57627357445, 'lake_reserve': 1606.3314357020072, 'river_reserve': 1727.2885668488652, 'current_price': 38} 4256.0 False
# {'ground_reserve': 100783.13014362885, 'lake_reserve': 1447.0092033304936, 'river_reserve': 1505.6983491623378, 'current_price': 39} 3939.0 False
# {'ground_reserve': 101032.51954658142, 'lake_reserve': 1302.5330891720946, 'river_reserve': 1309.409521964417, 'current_price': 40} 3680.0 False
# {'ground_reserve': 101254.57775722115, 'lake_reserve': 1176.758842514817, 'river_reserve': 1142.56739759289, 'current_price': 41} 3403.0 False
# {'ground_reserve': 101451.15654569643, 'lake_reserve': 1063.14937514345, 'river_reserve': 995.8936789337442, 'current_price': 42} 3150.0 False
# {'ground_reserve': 101624.11206526645, 'lake_reserve': 958.8262118313714, 'river_reserve': 864.7940287932028, 'current_price': 43} 2924.0 False
# {'ground_reserve': 101778.04344921863, 'lake_reserve': 866.8644830708935, 'river_reserve': 752.7157414422065, 'current_price': 44} 2684.0 False
# {'ground_reserve': 101913.16696947067, 'lake_reserve': 782.3863463862328, 'river_reserve': 652.2045568260218, 'current_price': 45} 2520.0 False
# {'ground_reserve': 102033.52075233926, 'lake_reserve': 707.7376555215587, 'river_reserve': 566.4715308608561, 'current_price': 46} 2300.0 False
# {'ground_reserve': 102139.6298610494, 'lake_reserve': 639.2151974740451, 'river_reserve': 490.13851215557327, 'current_price': 47} 2115.0 False
# {'ground_reserve': 102235.26583020066, 'lake_reserve': 581.3579690307564, 'river_reserve': 428.2050250701607, 'current_price': 48} 1968.0 False
# {'ground_reserve': 102320.36248658135, 'lake_reserve': 528.2249537561787, 'river_reserve': 373.13799959876707, 'current_price': 49} 1813.0 False
# {'ground_reserve': 102396.0994918551, 'lake_reserve': 480.3301193162119, 'river_reserve': 324.98377580845414, 'current_price': 50} 1700.0 False
# {'ground_reserve': 102463.10124778457, 'lake_reserve': 435.08306480626476, 'river_reserve': 280.96784500470136, 'current_price': 51} 1530.0 False
# {'ground_reserve': 102523.01352199489, 'lake_reserve': 395.9462633915517, 'river_reserve': 244.33544183662303, 'current_price': 52} 1456.0 False
# {'ground_reserve': 102575.71640729997, 'lake_reserve': 358.5774124293254, 'river_reserve': 210.18411687412183, 'current_price': 53} 1325.0 False
# {'ground_reserve': 102621.71605388794, 'lake_reserve': 323.9010275903162, 'river_reserve': 179.14240069161372, 'current_price': 54} 1242.0 False
# {'ground_reserve': 102664.76915936609, 'lake_reserve': 296.71910669431827, 'river_reserve': 157.7383879512445, 'current_price': 55} 1100.0 False
# {'ground_reserve': 102702.99168050801, 'lake_reserve': 270.4137107819927, 'river_reserve': 137.17269260250285, 'current_price': 56} 1008.0 False
# {'ground_reserve': 102737.72959886467, 'lake_reserve': 248.0699191067039, 'river_reserve': 120.82739759589066, 'current_price': 57} 969.0 False
# {'ground_reserve': 102768.97573719475, 'lake_reserve': 226.78032928834733, 'river_reserve': 105.64141045169387, 'current_price': 58} 870.0 False
# {'ground_reserve': 102795.74606339623, 'lake_reserve': 205.10300584316377, 'river_reserve': 89.32815626108844, 'current_price': 59} 826.0 False
# {'ground_reserve': 102821.01119534404, 'lake_reserve': 188.04494560335615, 'river_reserve': 78.71064106561555, 'current_price': 60} 720.0 False
# {'ground_reserve': 102844.57066384923, 'lake_reserve': 173.7573328418837, 'river_reserve': 70.98567920763296, 'current_price': 61} 671.0 False
# {'ground_reserve': 102867.98362327789, 'lake_reserve': 163.8443204026267, 'river_reserve': 68.21551234303386, 'current_price': 62} 620.0 False
# {'ground_reserve': 102888.13204971352, 'lake_reserve': 150.19293856229575, 'river_reserve': 60.31027385864513, 'current_price': 63} 567.0 False
# {'ground_reserve': 102908.37178365013, 'lake_reserve': 141.21674244305422, 'river_reserve': 57.83311864401565, 'current_price': 64} 512.0 False
# {'ground_reserve': 102925.53889073877, 'lake_reserve': 129.4864553186457, 'river_reserve': 51.039040679485225, 'current_price': 65} 520.0 False
# {'ground_reserve': 102940.81008365298, 'lake_reserve': 117.89944975089202, 'river_reserve': 44.13718656667531, 'current_price': 66} 462.0 False
# {'ground_reserve': 102955.38243896636, 'lake_reserve': 108.70281533046659, 'river_reserve': 39.9651061033375, 'current_price': 67} 402.0 False
# {'ground_reserve': 102969.3601226509, 'lake_reserve': 101.83211777015836, 'river_reserve': 37.96807545892679, 'current_price': 68} 408.0 False
# {'ground_reserve': 102982.38887073503, 'lake_reserve': 94.58333943544375, 'river_reserve': 35.33930971591062, 'current_price': 69} 345.0 False
# {'ground_reserve': 102995.08943170229, 'lake_reserve': 89.3091453801355, 'river_reserve': 34.53555360461472, 'current_price': 70} 350.0 False
# {'ground_reserve': 103007.57354424792, 'lake_reserve': 84.35650112093548, 'river_reserve': 34.054836092670165, 'current_price': 71} 284.0 False
# {'ground_reserve': 103020.29076432972, 'lake_reserve': 81.37027779703973, 'river_reserve': 35.46113596865041, 'current_price': 72} 288.0 False
# {'ground_reserve': 103033.26833414167, 'lake_reserve': 78.52795652648733, 'river_reserve': 37.03340550822484, 'current_price': 73} 219.0 False
# {'ground_reserve': 103045.53191354575, 'lake_reserve': 74.857684832891, 'river_reserve': 37.05821990621785, 'current_price': 74} 222.0 False
# {'ground_reserve': 103056.50061191477, 'lake_reserve': 69.79169972980687, 'river_reserve': 34.87712714085229, 'current_price': 75} 225.0 False
# {'ground_reserve': 103068.28564904597, 'lake_reserve': 68.15219080884052, 'river_reserve': 36.56399074178499, 'current_price': 76} 228.0 False
# {'ground_reserve': 103080.74257515793, 'lake_reserve': 66.99334469892581, 'river_reserve': 38.97805788131818, 'current_price': 77} 154.0 False
# {'ground_reserve': 103091.43642977194, 'lake_reserve': 62.371995324599965, 'river_reserve': 36.677733462644795, 'current_price': 78} 156.0 False
# {'ground_reserve': 103101.35609830011, 'lake_reserve': 58.05737702265725, 'river_reserve': 34.413186654526925, 'current_price': 79} 158.0 False
# {'ground_reserve': 103110.58536087218, 'lake_reserve': 54.11266160234116, 'river_reserve': 32.29814584151128, 'current_price': 80} 160.0 False
# {'ground_reserve': 103120.15765036237, 'lake_reserve': 52.3605278025627, 'river_reserve': 32.642246707929715, 'current_price': 81} 162.0 False
# {'ground_reserve': 103128.88178097764, 'lake_reserve': 48.49598628082696, 'river_reserve': 30.5924111102874, 'current_price': 82} 82.0 False
# {'ground_reserve': 103138.88638988123, 'lake_reserve': 48.564687122302416, 'river_reserve': 33.181044336206355, 'current_price': 83} 83.0 False
# {'ground_reserve': 103148.58151757126, 'lake_reserve': 47.53663754643199, 'river_reserve': 34.148463823035485, 'current_price': 84} 84.0 False
# {'ground_reserve': 103157.41486878101, 'lake_reserve': 44.990041087634125, 'river_reserve': 32.9924515605386, 'current_price': 85} 85.0 False
# {'ground_reserve': 103164.7649753877, 'lake_reserve': 40.589292995079745, 'river_reserve': 29.31602642474602, 'current_price': 86} 86.0 False
# {'ground_reserve': 103173.91424139928, 'lake_reserve': 41.56796509057728, 'river_reserve': 32.181425526028306, 'current_price': 87} 87.0 False
# {'ground_reserve': 103182.36014109732, 'lake_reserve': 40.387725576751215, 'river_reserve': 32.18397921746506, 'current_price': 88} 88.0 False
# {'ground_reserve': 103189.57437593144, 'lake_reserve': 37.21496969110896, 'river_reserve': 29.548102135759642, 'current_price': 89} 89.0 False
# {'ground_reserve': 103198.09776428965, 'lake_reserve': 37.9405738966659, 'river_reserve': 31.652168390518476, 'current_price': 90} 90.0 False
# {'ground_reserve': 103207.87654759115, 'lake_reserve': 40.43611264492232, 'river_reserve': 35.84894672387038, 'current_price': 91} 91.0 False
# {'ground_reserve': 103217.55951868654, 'lake_reserve': 41.232540628123914, 'river_reserve': 37.81410111110061, 'current_price': 92} 92.0 False
# {'ground_reserve': 103217.55951868654, 'lake_reserve': 41.232540628123914, 'river_reserve': 37.81410111110061, 'current_price': 93} 0 True
# Days sustained:  82
# Total_reward:  358392.0

# %% [markdown]
# ### Always decrease the price

# %%
# Always decrease price

# rainfall level can be set to low, medium or high.
rainfall_level = "low"

env = WaterEnv()

env.reset()
env.set_rainfall_level(rainfall_level)

for i in range(100000):
  action = "decrease_price"
  state, reward, terminated = env.step(action)
  if terminated:
    break

print("Days sustained: ", i)
print("Total_reward: ", env.total_reward)
# Out:
# Days sustained:  29
# Total_reward:  217519.0

# %% [markdown]
# ### Constant prices

# %%
# Always decrease price

# rainfall level can be set to low, medium or high.
rainfall_level = "low"

env = WaterEnv()

env.reset()
env.set_rainfall_level(rainfall_level)

for i in range(100000):
  action = "constant_price"
  state, reward, terminated = env.step(action)
  if terminated:
    break

print("Days sustained: ", i)
print("Total_reward: ", env.total_reward)
# Out:
# Days sustained:  65
# Total_reward:  1213740.0
